# %% [markdown]
# <b>¡Hola Juan!</b>
#
# Mi nombre es Alejandro Abia Trujillo y tengo el gusto de revisar tu proyecto.
#
# A continuación, encontrarás mis comentarios en celdas pintadas de tres colores (verde, amarillo y rojo), a manera de semáforo. Por favor, <b>no las borres ni muevas de posición</b> mientras dure el proceso de revisión.
#
# <div class="alert alert-block alert-success">
# <b>Éxito</b> <a class="tocSkip"></a>
#
# En celdas verdes encontrarás comentarios en relación a tus aciertos y fortalezas.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Antención</b> <a class="tocSkip"></a>
#
# Utilizaré el color amarillo para llamar tu atención, expresar algo importante o compartirte alguna idea de valor.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# En rojo emitiré aquellos puntos que deberás atender para aprobar la revisión.
#
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Comentario estudiante</b><a class="tocSkip"></a>
#
# Es factible que, a lo largo del proceso de revisión, quieras dejarme comentarios. Si es el caso, por favor realízalo dentro de celdas azules como esta.
#
# </div>
#
# Respecto del proceso de revisión, tu proyecto será aceptado una vez que los comentarios en rojo hayan sido atendidos.
#
# ¡Empecemos!
# ___________________________________

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Comentario segunda revisión
#
# Hola Juan. Aprecio que hayas incuído todas tus conclusiones en azul. Le da mucha claridad a tu proyecto. Estoy señalando en rojo dos respuestas hacia el final de tu poyecto. Pude haberlo señalado en amarillo pero, me interesa que conozcas las implementaciones que te estoy compartiendo.
#
# Para la versión de tu portafolio lo mejor sería traducir el contenido en inglés a español (o viceversa). Frente a un potencial empleador, tener contenidos en los dos idiomas puede malinterpretarse como si estuvieras tomando código de una fuente en inglés y no lo hubieras traducido.
#
#
# Gracias por considerar mis comentarios.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Comentario primera revisión
#
# Juan vas muy bien. Presentaste un excelente avance. Por favor atiende los comentarios en rojo para que pueda aprobar tu proyecto.
#
# Te falta también emitir las conclusiones del Paso 2 y, todo el Paso 3.
#
# Si tienes alguna duda para terminar su proyecto, no olvides contactar a tu Tutor.
#
# Yo también te puedo ayudar con dudas puntales, para mi siempre será un gusto.
#
# ¡Saludos!
#
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Antención</b> <a class="tocSkip"></a>
#
# Bien por utilizar las abreviaturas aceptadas (ps) para importar pandas. Recomiendo también importar matplotlib porque sin duda la estarás utilizando más adelante.
#
#     import matplotlib.pyplot as plt
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Listo, he importado esta librería.
#
# </div>

# %%
# leer conjuntos de datos en los DataFrames
orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products = pd.read_csv('/datasets/products.csv', sep=';')
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
departments = pd.read_csv('/datasets/departments.csv', sep=';')
order_products= pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
# mostrar información del DataFrame
orders.info()
print()
print("###################################################################################################")
#print(orders.head()) en lugar de print(orders.head()); utilizar orders.head()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#
# ###################################################################################################
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Antención</b> <a class="tocSkip"></a>
#
# Buen trabajo con esta exploración inicial. Cuando trabajas en un cuaderno como este, recomiendo no utilizar la función print() en conjunción con el método head(). Esto es, si en lugar de utilizar print(orders.head()), utilizas orders.head(), el resultado será mucho más limpio.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Listo, en lugar de utilizar la función print() en conjunto con el método head(), voy a utilizar "df.head()" para mostrar un código más limpio.
#
# </div>

# %% [markdown]
# Corregido

# %%
# mostrar información del DataFrame
products.info()
print()
print("###################################################################################################")
products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#
# ###################################################################################################
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# ...

# %%
# mostrar información del DataFrame
aisles.info()
print()
print("###################################################################################################")
aisles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#
# ###################################################################################################
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# mostrar información del DataFrame
departments.info()
print()
print("###################################################################################################")
departments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#
# ###################################################################################################
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# mostrar información del DataFrame
order_products.info(show_counts=True) #Por defecto, si el DataFrame tiene demasiadas filas, info() no mostrará conteos no nulos. Si queremos ver los conteos para order_products, debemos incluir show_counts=True.
print()
order_products
print("###################################################################################################")
order_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#
# ###################################################################################################
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Por defecto, si el DataFrame tiene demasiadas filas, `info()` no mostrará conteos no nulos. Si queremos ver los conteos para `order_products`, debemos incluir `show_counts=True`.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Originalmente me llamaba la atención que el método info() no presentara conteos de no-nulos. Para corregirlo, he agregado el parámetro "show_values" con el argumento "True".
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Utilizaste los métodos info() y head() para realizar la exploración inicial de los cinco conjuntos de datos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones:
#
#     Todos los cinco datasets tienen separador de punto y coma (";"). Para todos he aplicado los métodos .info() y .head() pues necesito un primer overview de cada uno.
#
#     Dataframe "orders":
#     * Entries: 478967 -- se interpreta como el total de órdenes registradas
#     * El campo "order_id" tiene el type esperado (número entero)
#     * El campo "user_id" tiene el type esperado (número entero)
#     * El campo "order_number" tiene el type esperado (número entero)
#     * El campo "order_dow" tiene el type esperado (número entero)
#     * El campo "order_hour_of_day" muestra un valor de número entero, y es posible que haya que transformarlo
#     * El campo "days_since_prior_order" es type flotante y se esperaba un entero. Además contiene valores nulos, pero esto sí es esperable sus valores son cero o uno.
#
#     Dataframe "products":
#     * Entries: 49694 -- se interpreta que es el total de productos ofrecidos
#     * El campo "product_id" tiene el type esperado de número entero
#     * El campo "product_name" tiene el type esperado "object" pues es un string
#     * El campo "aisle_id" tiene el type esperado de número entero
#     * El campo "department_id" tiene el type esperado de número entero
#
#     * No se muestran valores nulos, este dataset es estático
#
#     Dataframe "aisles":
#     * Entries: 134 -- se interpreta que hay 134 categorías de productos (ej: preparados, ensaladas, comida instantánea, etc)
#     * El campo "aisle_id" tiene el type esperado de número entero
#     * El campo "aisle" tiene el type esperado "object" pues es un string
#
#     * No se muestran valores nulos, este dataset es estático
#
#     Dataframe "departments":
#     * Entries: 21 -- se interpreta que hay 21 departamentos de productos (ej: congelados, panificados, verduras, etc)
#     * El campo "aisle_id" tiene el type esperado de número entero
#     * El campo "aisle" tiene el type esperado "object" pues es un string
#
#     * No se muestran valores nulos, este dataset es estático
#
#     Dataframe "order_products":
#     * Entries: 4545007 -- cada fila es un artículo comprado dentro de un pedido
#     * El campo "order_id" tiene el type esperado de número entero
#     * El campo "product_id" tiene el type esperado de número entero
#     * El campo "add_to_cart_order" es type flotante y se esperaba un entero
#     * El campo "reordered" tiene el type esperado de booleano
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# <div class="alert alert-block alert-info">
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
#     Plan de solución:
#
#     Tipos de datos:
#      * Verificar los tipos de datos
#      * Corregir los types en caso necesario
#
#     Valores AUSENTES:
#      * Detectar valores ausentes, y determinar si son esperables o no
#      * Reemplazar valores ausentes que puedan afectar al posterior análisis
#
#     Valores DUPLICADOS:
#      * Detectar duplicados, y determinar si son esperables o no
#      * Gestionar duplicados mediante eliminación o reemplazo
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# Tu plan de trabajo tiene todos los elementos esperados.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados

print(f"El total ORIGINAL de duplicados es de {orders.duplicated().sum()}")
print("\nLa siguiente tabla muestra los valores DUPLICADOS:")
orders[orders.duplicated()]
# Out:
# El total ORIGINAL de duplicados es de 15
#
# La siguiente tabla muestra los valores DUPLICADOS:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# La manera más fácil de revisar si hay duplicados es buscar filas totalmente duplicadas llamando a `duplicated()` en el dataframe sin ningún argumento.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
#     El dataframe "orders" presenta 15 registros duplicados cuando order_dow=3 y order_hour_of_day=2 (los días Miércoles a las 2am)
# </div>

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

#print(orders[(orders['order_dow']==3) & (orders['order_hour_of_day']==2)])
orders[(orders['order_dow']==3) & (orders['order_hour_of_day']==2)]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# ¿Qué sugiere este resultado?
#
#     El resultado establece que existen un total de 121 registros el día Miércoles a las 2am. De esos 121 registros, hay un total de 15 duplicados tal como visto anteriormente.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# ¡Tenemos algunas filas duplicadas! Lo que llama la atención de ellas es que todas ocurrieron para los pedidos que se hicieron a las 2:00 a.m. en un miércoles.
#
# </div>

# %%
# Elimina los pedidos duplicados

#Siempre que utilices .drop_duplicates() recomiendo reiniciar el índice añadiendo a tu código.reset_index(drop=True).
orders = orders.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
#
# Quiza hubo algún error del sistema que hizo que los datos del pedido se escribiesen dos veces durante un corto periodo de tiempo, solo en un miércoles en particular. Coincido en que podemos prescindir de estas observaciones.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Siempre que utilices .drop_duplicates() recomiendo reiniciar el índice añadiendo a tu código.reset_index(drop=True).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# He agregado el método con su parámetro y argumento: .reset_index(drop=True)
# </div>

# %%
# Vuelve a verificar si hay filas duplicadas
print(f"El total NUEVO de duplicados es de {orders.duplicated().sum()}")
print("\nLa siguiente tabla muestra que ya no quedan valores DUPLICADOS:")
orders[orders.duplicated()]
# Out:
# El total NUEVO de duplicados es de 0
#
# La siguiente tabla muestra que ya no quedan valores DUPLICADOS:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos

print("\nLa siguiente tabla muestra que ya no quedan valores DUPLICADOS del campo \"order_id\":")
orders[orders['order_id'].duplicated()]
# Out:
# La siguiente tabla muestra que ya no quedan valores DUPLICADOS del campo "order_id":
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
#     * Hemos chequeado si habían órdenes de pedidos duplicados, y efectivamente se han encontrado un total de 15
#     * Se observa que los registros duplicados tenían condiciones en común (días Miércoles a las 2am)
#     * Para confirmar esta hipótesis, filtramos el dataframe con estas condiciones
#     * Luego a través de una gestión de duplicados, se eliminan aquellos pedidos duplicados
#     * Por último, chequeamos que esos duplicados ya no aparezcan en el dataframe
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(f"El total ORIGINAL de duplicados es de {products.duplicated().sum()}")
print("####################################################### \nLa siguiente tabla muestra los valores DUPLICADOS:")
print(products[products.duplicated()])
# Out:
# El total ORIGINAL de duplicados es de 0
# #######################################################
# La siguiente tabla muestra los valores DUPLICADOS:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Verifica únicamente si hay IDs duplicadas de productos
print( products['product_id'].duplicated().sum() )
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Sólo por añadir valor, considera que también podrías hacer uso de:
#
#     products[products.duplicated(subset='product_id')]
#
#
# </div>

# %%
# Revisa únicamente si hay nombres duplicados de productos (convert los nombres a letras mayúsculas para compararlos mejor)
print(f"La cantidad de duplicados del campo \"product_name\" es {products['product_name'].duplicated().sum()}" )
products['product_name'] = products['product_name'].str.upper()

products[products['product_name'].duplicated()]
# Out:
# La cantidad de duplicados del campo "product_name" es 1257
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes
products_duplicados = products[products['product_name'].duplicated()]
products_duplicados[~products_duplicados['product_name'].isna()]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#     Análisis de duplicados de la tabla "products"
#
#     * Se han encontrado un total de 0 duplicados completos
#     * Se han encontrado un total de 0 duplicados en el campo "product_id"
#     * Se han encontrado un total de 1361 duplicados en el campo "product_name". De estos 1361, hay 104
#       valores no nulos -- este hallazgo induce a pensar que habría que eliminar estos registros, sin embargo
#       como no hay duplicados en "product_id", optaré por conservarlos
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Creo que tomas la mejor decisión posible. Los registros duplicados tienen distintas IDs de producto. Coincido en que no son duplicados.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(f"El total ORIGINAL de duplicados es de {departments.duplicated().sum()}")
print("\nLa siguiente tabla confirma que no hay valores DUPLICADOS:")
departments[departments.duplicated()]
# Out:
# El total ORIGINAL de duplicados es de 0
#
# La siguiente tabla confirma que no hay valores DUPLICADOS:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print( departments['department_id'].duplicated().sum() )
print( departments['department'].duplicated().sum() )
# Out:
# 0
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#     No se observan duplicados, por lo que no hace falta un análisis ulterior.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# No hay duplicados!
#
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(f"El total ORIGINAL de duplicados es de {aisles.duplicated().sum()}")
print("\nLa siguiente tabla confirma que no hay valores DUPLICADOS:")
aisles[aisles.duplicated()]
# Out:
# El total ORIGINAL de duplicados es de 0
#
# La siguiente tabla confirma que no hay valores DUPLICADOS:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print( aisles['aisle_id'].duplicated().sum() )
print( aisles['aisle'].duplicated().sum() )
# Out:
# 0
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#     No se observan duplicados, por lo que no hace falta un análisis ulterior.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# Tampoco aquí hay duplicados.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(f"El total ORIGINAL de duplicados es de {order_products.duplicated().sum()}")
print("\nLa siguiente tabla muestra los valores DUPLICADOS:")
order_products[order_products.duplicated()]
# Out:
# El total ORIGINAL de duplicados es de 0
#
# La siguiente tabla muestra los valores DUPLICADOS:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(f"Valores duplicados del campo order_id: {order_products['order_id'].duplicated().sum()}")
print(f"Valores duplicados del campo product_id: {order_products['product_id'].duplicated().sum()}")

print("\nSe observa que no hay valores duplicados de los campos combinados \"order_id\" y \"product_id\":")
order_products[order_products.duplicated(subset=['order_id', 'product_id'])]
# Out:
# Valores duplicados del campo order_id: 4094961
# Valores duplicados del campo product_id: 4499434
#
# Se observa que no hay valores duplicados de los campos combinados "order_id" y "product_id":
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#     En este Dataframe "order_products" cada fila corresonde a un artículo pedido en un pedido, por lo cual es esperable que se observen duplicados de "order_id" y "product_id" si los evaluamos por SEPARADO.
#     Sin embargo, los registros de este dataset deben tener una combinación unívoca en los campos "order_id" y "product_id". Esta combinación no muestra duplicados.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Para esta tabla, es un poco complicado revisar si hay identificadores únicos duplicados, ya que no hay una única columna que identifique cada fila de manera exclusiva. En cambio, lo que debe ser único en esta tabla es la combinación de las columnas `'order_id'` y `'product_id'`, ya que ningún producto debe aparecer más de una vez para cada pedido. Por lo tanto, aquí creo que puedes echar mano de...
#
#     order_products[order_products.duplicated(subset=['order_id', 'product_id'])]
#
# Tus conclusiones no cambiarán.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# He agregado esta línea de código para mejorar la aclaración
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
products.isna().sum()
#products.value_counts()
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#     El campo "product_name" presenta un total de 1258 valores ausentes. Aparentemente estos ausentes están relacionados con aisle_id=100 y con department_id=21.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente trabajo</b> <a class="tocSkip"></a>
#
# Así es, cada nombre de producto ausente es del departamento 21 y del pasillo 100.
#
# </div>

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print("Filtramos el dataset con estas condiciones, y observamos que se presentan un total de 1258 registros con \n valores ausentes en el campo \"product_name\", lo cual confirma nuestra hipótesis previa: \n")
products[(products['product_name'].isna()) & (products['aisle_id']==100)]
# Out:
# Filtramos el dataset con estas condiciones, y observamos que se presentan un total de 1258 registros con
#  valores ausentes en el campo "product_name", lo cual confirma nuestra hipótesis previa:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %%
print("Ahora filtramos el dataset pero excluyendo la segunda condición, y vemos que no arroja ningún registro, lo cual nuevamente confirma nuestra hipótesis: \n")
products[(products['product_name'].isna()) & (products['aisle_id']!=100)]
# Out:
# Ahora filtramos el dataset pero excluyendo la segunda condición, y vemos que no arroja ningún registro, lo cual nuevamente confirma nuestra hipótesis:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#        Se observa un total de 1258 valores ausentes en el campo "product_name" para los registros combinados de los siguientes campos y valores:
#         * "product_name" == null
#         * "aisle_id" == 100
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# ~~Arriba sugiero la siguiente línea para contestar a la pregunta.~~
#
#     products[(products['product_name'].isna()) & (products['aisle_id'] != 100)]
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# He agregado esa línea para un mejor análisis
# </div>

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
print("Filtramos el dataset con estas condiciones y se observan esos 1258 registros: \n")
products[ (products['product_name'].isna()) & (products['department_id']==21) ]
# Out:
# Filtramos el dataset con estas condiciones y se observan esos 1258 registros:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %%
print("Ahora filtramos el dataset pero excluyendo la segunda condición, y vemos que no arroja ningún registro: \n")
products[ (products['product_name'].isna()) & (products['department_id']!=21) ]
# Out:
# Ahora filtramos el dataset pero excluyendo la segunda condición, y vemos que no arroja ningún registro:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#        Se observa un total de 1258 valores ausentes en el campo "product_name" para los registros combinados de los siguientes campos y valores:
#         * "product_name" == null
#         * "department_id" == 21
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# ~~Paralelamente, aquí recomiendo:~~
#
#     products[(products['product_name'].isna()) & (products['department_id'] != 21)]
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# He agregado esa línea para un mejor análisis
# </div>

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print("Ahora, buscaremos alguna característica de estos valores ausentes en sus tablas de origen: \n ")
aisles_ids_ausentes = aisles[aisles['aisle_id']==100]['aisle']
departments_ids_ausentes = departments[departments['department_id']==21]['department']

print(f"Valores ausentes en campo \"aisle\" de la tabla \"aisles\": {aisles_ids_ausentes}")
print()
print(f"Valores ausentes en campo \"department\" de la tabla \"departments\": {departments_ids_ausentes}")
# Out:
# Ahora, buscaremos alguna característica de estos valores ausentes en sus tablas de origen:
#
# Valores ausentes en campo "aisle" de la tabla "aisles": 99    missing
# Name: aisle, dtype: object
#
# Valores ausentes en campo "department" de la tabla "departments": 20    missing
# Name: department, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# ~~Arriba puedes echar mano de:~~
#
#     print(departments[departments['department_id'] == 21]['department'])
#     print()
#     print(aisles[aisles['aisle_id'] == 100]['aisle'])
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Corregido.
# </div>

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna(value='Unknown')

print(f"Chequeamos de que se hayan reemplazado estos valores del campo \"product_name\" en la tabla \"products\".")
products[(products['aisle_id']==100) & (products['department_id']==21)]
# Out:
# Chequeamos de que se hayan reemplazado estos valores del campo "product_name" en la tabla "products".
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49552       49553      Unknown       100             21
# 49574       49575      Unknown       100             21
# 49640       49641      Unknown       100             21
# 49663       49664      Unknown       100             21
# 49668       49669      Unknown       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# ~~Después de correr el código que he compartido podrás ver que tanto aisle como department están etiquetadas como `'missing'`. Estos deben ser datos basura, pero no podemos saberlo a ciencia cierta con los datos que tenemos. Por eso está bien reemplazar los valores ausentes con `'Unknown'`.~~
#
# ~~¡No olvides actualizar tus conclusiones para esta parte! Se verán bien en tu portafolio.~~
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# He seguido la sugerencia que me has propuesto, y efectivamente he encontrado que para 'department_id'==21 en la tabla 'departments' y 'aisle_id'==100 en la tabla 'aisles', estos dos dataframes presentan valores "Missing".
#
# En este enunciado, el ejercicio pide completar con 'Unknown' los valores ausentes de los nombres de prouctos en la tabla 'productos'. Para ello utilizo el método fillna() y luego chequeo que esto se haya aplicado.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones:
#
#     *En la tabla "products" se observan un total de 1258 registros con valores ausentes en el campo "product_name".
#     * Se detecta que esos registros ocurren para la combinación de los siguientes campos y valores:
#             * "product_name" == null
#             * "department_id" == 21
#     * Se buscan esos valores en su tabla de origen, constatando de que estos campos de ID tienen valores "Missing" en sus campos de NOMBRE.
#     * Se reeemplazan estos valores de "Missing" por "Unknown"
#     * Se constata de que estos valores han sido reemplazados
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print("En primer lugar, llamamos nuevamente al método .info() para ver qué campos presentan valores nulos vs. no-nulos.")
print("Del total de 478.952 entradas, observamos que el campo \"days_since_prior_order\" presenta un total de 450.135 \nvalores no-nulos.")
print("Habrá un total de 478.952-450.135=28.817 valores nulos")
print()
orders.info()

print("\n\nEn segundo lugar, revisamos aquellos campos que muestren valores nulos dentro del dataframe.")
print("Observamos que el campo \"days_since_prior_order\" presenta un total de 28.817 valores nulos, lo que coincide con el cálculo anterior.")
print()
print(orders.isna().sum())

print("\n\nEn tercer lugar, revisaremos el dataframe para buscar patrones.")
print("Filtramos el dataframe con la condición de valores nulos en el campo \"days_since_prior_order\".")
print()
print(orders[orders['days_since_prior_order'].isna()])
print("\nObservación1: hemos hallado un total de 28.817 registros con valores nulos, a priori parecen estar asociados \ncon el primer pedido ya que se repite el patrón \"order_number\"==1.")
print()
print("Ahora aplicamos un nuevo filtro para excluir los registros en donde el campo \"order_number\" sea diferente al valor \"1\".")
print("Observamos que este filtro arroja cero registros, lo cual confirma nuestra sospecha.")
print(orders[(orders['days_since_prior_order'].isna()) & (orders['order_number']!=1)])
print()
print("Obsevación2: este último filtro nos afirma que el total de valores nulos es de 28.817 y están relacionados con el primer pedido.")
# Out:
# En primer lugar, llamamos nuevamente al método .info() para ver qué campos presentan valores nulos vs. no-nulos.
# Del total de 478.952 entradas, observamos que el campo "days_since_prior_order" presenta un total de 450.135
# valores no-nulos.
# Habrá un total de 478.952-450.135=28.817 valores nulos
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478952 entries, 0 to 478951
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_dow               478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  450135 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Aquí recomiendo hacer uso de la siguiente línea de código.
#
#     orders[orders['days_since_prior_order'].isna()]
#
# A primera vista, parece que estos valores ausentes están en las filas que corresponden al primer pedido de los clientes. Luego puedes echar mano de:
#
#     orders[(orders['days_since_prior_order'].isna()) & (orders['order_number'] != 1)]
#
# En contrarás un dataframe vacío. Todos los valores 'days_since_prior_order' ausentes corresponden a la primera compra de los clientes.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Comentario del estudiante
# Corregido y explicado junto al código.
#
# </div>

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#     No. Todos los registros con valores ausentes en el campo "days_since_prior_order" corresponden al primer pedido.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
#     * El total de registros del dataframe "orders" es de 478.952
#     * El total de registros con valores NO NULOS del campo "days_since_prior_order" es de 450.135
#     * El total de registros con valores NULOS del campo "days_since_prior_order" es de 28.817
#
#     * Comprobamos esta cantidad mediante el cálculo 478.952 - 450135 = 28.817
#
#     Hemos filtrado los valores nulos del dataframe y luego los campos que presentaban valores nulos.
#     Hemos realizado un análisis inicial y se observa un patrón, y se toma este patrón como hipótesis de que los valores nulos están ligados a él.
#     Luego filtramos con este patrón de 'order_number_id'!=1 y efectivamente nos arroja un dataset vacío, y de esta forma comprobamos la hipótesis.
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes

print("Llamamos al método .info() y vemos que el campo \"add_to_cart_order\" presenta 4.545.007-4.544.171=836 valores nulos.\n")
order_products.info(show_counts=True)
print("\n\nLlamamos al método .isna() y constatamos el total de valores nulos de 836 en el campo \"add_to_cart_order\" .\n")
print(order_products.isna().sum())
# Out:
# Llamamos al método .info() y vemos que el campo "add_to_cart_order" presenta 4.545.007-4.544.171=836 valores nulos.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#
#
# Llamamos al método .isna() y constatamos el total de valores nulos de 836 en el campo "add_to_cart_order" .
#
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?

print(f"valor min del campo \"add_to_cart_order\": {order_products['add_to_cart_order'].min()}")
print(f"valor max del campo \"add_to_cart_order\": {order_products['add_to_cart_order'].max()}")
print()
print("Un valor máximo de 64 resulta curioso, lo que llama a verificar si cada pedido con valores ausentes tiene más de 64 artículos en ella.")
print()
print(order_products.describe())
# Out:
# valor min del campo "add_to_cart_order": 1.0
# valor max del campo "add_to_cart_order": 64.0
#
# Un valor máximo de 64 resulta curioso, lo que llama a verificar si cada pedido con valores ausentes tiene más de 64 artículos en ella.
#
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Un valor máximo de 64 resulta un tanto curioso, lo que llama a verificar si cada pedido con valores ausentes tiene más de 64 artículos en ella.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#     * El campo "add_to_cart_order" indica el orden secuencial en que se ha agregado el artículo dentro del carrito (o pedido).
#     * Los valores "uno" indican que ese carrito cuenta con ese producto una única vez, mientras que el valor de 64 indica indica el máximo número de productos que alguna vez han sido incluídos en un carrito.
#     * El valor promedio de artículos que se incluyen en cada pedido es de 8.35 art/carrito, lo cual induce a pensar que un carrito con 64 o más artículos es sospechoso.
#
# </div>

# %%
#Veamos aquí de qué se tratan esos valores ausentes del campo "add_to_cart_order"

print("Filtramos el dataframe con valores nulos en el campo \"add_to_cart_order\" para revisar si podemos observar algún patrón.")
print("Vemos que no resulta fácil detectar algún patrón. \n")
print(order_products[(order_products['add_to_cart_order'].isna())])
# Out:
# Filtramos el dataframe con valores nulos en el campo "add_to_cart_order" para revisar si podemos observar algún patrón.
# Vemos que no resulta fácil detectar algún patrón.
#
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'

#Queremos verificar si cada pedido con valores ausentes tiene más de 64 artículos en ella.
#Lo primero que necesitamos es la lista de order_id con valores ausentes en el campo "add_to_cart_order":

print("Listado de órdenes con valores nulos en el campo \"add_to_cart_order\":\n")
miss_cart_order_ids = sorted(list(order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()))
print(miss_cart_order_ids)
# Out:
# Listado de órdenes con valores nulos en el campo "add_to_cart_order":
#
# [9310, 61355, 102236, 129627, 165801, 171934, 180546, 264710, 293169, 388234, 404157, 678116, 733526, 747668, 813364, 844733, 854647, 871281, 888470, 903110, 936852, 1021563, 1038146, 1169835, 1183255, 1220886, 1302315, 1308785, 1386261, 1477139, 1529171, 1564093, 1598369, 1625713, 1633337, 1648217, 1673227, 1677118, 1713430, 1717990, 1730767, 1800005, 1832957, 1888628, 1916118, 1959075, 1961723, 1968313, 2094761, 2136777, 2170451, 2256933, 2409109, 2449164, 2470674, 2479011, 2621907, 2625444, 2652650, 2721963, 2729254, 2849370, 2926893, 2979697, 2997021, 2999801, 3125735, 3308010, 3347453, 3383594]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

print("\nAhora filtramos order_products para estos registros de order_id, y agrupamos por order_id.\n") 

orders_grp = order_products[order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id')
print(orders_grp.head())

print("\nContabilizamos la cantidad mínima y máxima de los pedidos con menor y mayor cantidad de productos.")
print(f"{orders_grp['product_id'].count().min()} es la cantidad de productos del pedido con menor diversidad (no ítems).")
print(f"{orders_grp['product_id'].count().max()} es la cantidad de productos del pedido con mayor diversidad (no ítems).")

print("\nLa siguiente es otra manera de visualizar este agrupamiento, en donde se muestra la cantidad de productos que contiene cada pedido: \n")
orders_grp2 = order_products[order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id')['product_id'].count()
print(orders_grp2.head())
# Out:
# Ahora filtramos order_products para estos registros de order_id, y agrupamos por order_id.
#
#         order_id  product_id  add_to_cart_order  reordered
# 267      2094761       31469               57.0          1
# 737      2449164        5068                NaN          0
# 1742     2997021        4920               37.0          0
# 3463      871281       40063               61.0          1
# 3535      171934       36397                7.0          0
# ...          ...         ...                ...        ...
# 607447   2170451       38200               18.0          1
# 650703   1916118       47766               32.0          1
# 722943   1598369       47335               59.0          1
# 838640   1598369        7631                4.0          1
# 840691   1598369       22128               33.0          1
#
# [350 rows x 4 columns]
#
# Contabilizamos la cantidad mínima y máxima de los pedidos con menor y mayor cantidad de productos.
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#     Hemos encontrado el siguiente patrón: en la tabla order_products resulta que los registros con valores nulos corresponden a aquellos pedidos que llevan 65 ó más productos diferentes (no en cantidad de ítems).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>A resolver</b> <a class="tocSkip"></a>
#
# ~~Retomando mi comentario de arriba, queremos verificar si cada pedido con valores ausentes tiene más de 64 artículos en ella.~~
#
# ~~Lo primero que necesitamos es la lista de order_id con valores ausentes:~~
#
#     miss_cart_order_ids = sorted(list(order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()))
#
# ~~Luego filtrar order_products para estos registros de order_id y, agrupar por order_id y luego contar el número de filas.~~
#
#     orders_grp = order_products[order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id')~~
#     orders_grp['product_id'].count().min()
#
# ~~Derivado del proceso anterior deberías obtener 65.~~
#
# ~~Esto quiere decir que cada pedido con un valor ausente tiene más de 64 artículos y los datos son razonables.~~
#
# ~~Ya que no podemos saber en qué pedido se agregaron al carrito los artículos con valores ausentes para aquellos pedidos con más de 65 artículos, la sugerencia es completar los valores ausentes con un valor de marcador de posición numérico que no pueda confundirse con datos reales; por ejemplo, 999.~~
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Comentario del estudiante
# Corregido y explicado junto al código, finalmente logro llegar al resultado de 65.
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.

order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(value=999)
print(order_products[(   order_products['add_to_cart_order']==999  )]   )
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068              999.0          0
# 9926      1968313       43867              999.0          0
# 14394     2926893       11688              999.0          0
# 16418     1717990        4142              999.0          0
# 30114     1959075       42828              999.0          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411              999.0          0
# 4511400   1633337         260              999.0          0
# 4517562    404157        9517              999.0          0
# 4534112   1673227       17835              999.0          0
# 4535739   1832957       17949              999.0          1
#
# [836 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# Describe brevemente cuáles son tus hallazgos.
#
#     Los valores ausentes del campo "add_to_cart_order" corresponden a aquellos pedidos con más de 65 productos. Hemos encontrado que La mejor forma de convivir con estos valores ausentes es reemplazarlos por un valor que los identifique sin afectar a la integridad del dataframe, en este caso hemos reemplazado esos ausentes por el valor "999".
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Atención</b> <a class="tocSkip"></a>
#
# ~~Es necesario trabajar en el resto del proyecto. Esto es, en las conclusiones de esta sección y en el Análisis de Datos. ~~
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * Previo a entrar en la fase de análisis de datos, hemos realizado una gestión de duplicados, y luego gestión de valores ausentes. Para esta última fase, hemos visto de manera diversa que a veces conviene reemplazar esos valores en lugar de simplemente eliminarlos. Es necesario estudiar su patrón y su origen para comprender la razón de su existencia, en función de evitar errores en el análisis de datos ulterior a esta etapa.
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` de la tabla `orders` sean sensibles (es decir, `'order_hour_of_day'` va de 0 a 23 y `'order_dow'` va de 0 a 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
orders['order_hour_of_day'].unique()
# Out:
# array([13, 12, 19, 20, 11,  8, 18, 15, 16,  9, 22, 10,  0, 14, 17,  1,  7,
#         6,  2, 21,  3, 23,  5,  4])

# %%
orders['order_dow'].unique()
# Out:
# array([6, 5, 0, 4, 3, 1, 2])

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     Ambas variables tienen los valores esperados.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# Correctamente verificado que los datos son razonables.
#
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
order_id_counts_per_hour = orders['order_hour_of_day'].value_counts().reset_index()
order_id_counts_per_hour.columns = ['order_hour_of_day', 'count']
order_id_counts_per_hour.sort_values(by=['order_hour_of_day'], ascending=True, inplace=True)
print(order_id_counts_per_hour)

order_id_counts_per_hour.plot(x='order_hour_of_day', y='count', kind='bar')
plt.show()
# Out:
#     order_hour_of_day  count
# 18                  0   3180
# 19                  1   1763
# 21                  2    989
# 22                  3    770
# 23                  4    765
# 20                  5   1371
# 17                  6   4215
# 13                  7  13043
# 10                  8  25024
# 7                   9  35896
# 0                  10  40578
# 1                  11  40032
# 6                  12  38034
# 4                  13  39007
# 3                  14  39631
# 2                  15  39789
# 5                  16  38112
# 8                  17  31930
# 9                  18  25510
# 11                 19  19547
# 12                 20  14624
# 14                 21  11019
# 15                 22   8512
# 16                 23   5611

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * La mayor cantidad de pedidos se registra entre la franja horaria de 9 a 16hs, con valores que oscilan entre los 35.000 y 40.000 pedidos
#     * A las 10am es la hora pico junto a las 11am, alcanzando valores de 40.000 pedidos
#     * Entre las 0 y las 6 se observa un nivel muy bajo de pedidos, por debajo de los 4.000
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Excelente</b> <a class="tocSkip"></a>
#
# Cálculos correctos, conclusiones certeras.
#
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
order_id_counts_per_day = orders['order_dow'].value_counts().reset_index()
order_id_counts_per_day.columns = ['order_dow', 'count']
order_id_counts_per_day.sort_values(by=['order_dow'],ascending=True, inplace=True)
print(order_id_counts_per_day)

order_id_counts_per_day.plot(x='order_dow', y='count', kind='bar')
plt.show()
# Out:
#    order_dow  count
# 0          0  84090
# 1          1  82185
# 2          2  65833
# 5          3  60897
# 6          4  59810
# 3          5  63488
# 4          6  62649

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * The highests amounts of orders are registered during days 0 and 1 (Sundays and Mondays, respectively), above 80.000 orders
#     * From Tuesdays to Saturdays the amount of orders stays on an average of 60.000
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Los cálculos y las conclusiones son correctos. Quizá valga la pena homologar el contenido a español para la versión de tu portafolio.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
print("Para el campo \"days_since_prior_order\", podemos observar los siguientes valores:\n")

print(f"Valor mínimo: {orders['days_since_prior_order'].min()}")
print(f"Valor máximo: {orders['days_since_prior_order'].max()}")
print(f"\nValores estadísticos en general del campo \"days_since_prior_order\": \n{orders['days_since_prior_order'].describe()}")
# Out:
# Para el campo "days_since_prior_order", podemos observar los siguientes valores:
#
# Valor mínimo: 0.0
# Valor máximo: 30.0
#
# Valores estadísticos en general del campo "days_since_prior_order":
# count    450135.000000
# mean         11.101814
# std           9.190004
# min           0.000000
# 25%           4.000000
# 50%           7.000000
# 75%          15.000000
# max          30.000000
# Name: days_since_prior_order, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     Recordemos que los valores ausentes en el campo "days_since_prior_order" están asociados al primer pedido, y no generan una anomalía en los datos.
#     Hay usuarios que no esperan ni un día para hacer el próximo pedido, y por eso se muestra el valor cero como mínimo.
#     En promedio, un usuario realiza un nuevo pedido en 11.1 días.
#     El máximo valor registrado para espera de un nuevo pedido es de 30 días -- este valor es muy diferente del resto
# </div>

# %%
print("Analicemos la distribución de la cantidad de días que suceden entre órdenes")

days_between_orders = orders['days_since_prior_order'].value_counts().reset_index()
days_between_orders.columns = ['days_since_prior_order', 'count']
days_between_orders.sort_values(by=['days_since_prior_order'], ascending=True, inplace=True)
print(days_between_orders.head())

days_between_orders.plot(x='days_since_prior_order', y='count', kind='bar')
# Out:
# Analicemos la distribución de la cantidad de días que suceden entre órdenes
#     days_since_prior_order  count
# 15                     0.0   9589
# 8                      1.0  20179
# 6                      2.0  27138
# 4                      3.0  30224
# 3                      4.0  31006
# <AxesSubplot:xlabel='days_since_prior_order'>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     Efectivamente, el máximo valor registrado para espera de un nuevo pedido es de 30 días. Si bien es un valor poco común; aún así es un valor real.
#     Esto provoca que la media (11.1 días) sea mayor que la mediana (7.0 días).
#     En este caso, la mediana resultará un indicador más significativo de la muestra.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Buen trabajo Juan, los cálculos son correctos y tu observación sobre la mediana es muy pertinente.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
order_id_counts_per_day = orders['order_dow'].value_counts().reset_index()
order_id_counts_per_day.columns = ['order_dow', 'count']
order_id_counts_per_day.sort_values(by=['order_dow'], ascending=True, inplace=True)
#print(order_id_counts_per_day)

order_id_counts_per_day_filtered = order_id_counts_per_day[(order_id_counts_per_day['order_dow']==3 ) | (order_id_counts_per_day['order_dow']==6)]
#print(order_id_counts_per_day_filtered)

print("\nThe following chart shows that there is no big difference in the total amount of orders on both days.")
#order_id_counts_per_day.plot(x='order_dow', y='count', kind='bar')
order_id_counts_per_day_filtered.plot(x='order_dow', y='count', kind='bar')
# Out:
# The following chart shows that there is no big difference in the total amount of orders on both days.
# <AxesSubplot:xlabel='order_dow'>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     Regarding the total amount of orders, there is no significative difference between Wednesdays and Saturdays.
# </div>

# %%
print("Distribution of daytime vs orders on WEDNESDAYS")
order_id_counts_per_hour = orders.query("order_dow==3")['order_hour_of_day'].value_counts().reset_index()
#print(order_id_counts_per_hour)

order_id_counts_per_hour.columns = ['order_hour_of_day', 'count']
#print(order_id_counts_per_hour)

order_id_counts_per_hour.sort_values(by=['order_hour_of_day'], ascending=True, inplace=True)
#print(order_id_counts_per_hour)

order_id_counts_per_hour.plot(x='order_hour_of_day', y='count', kind='bar')
plt.show()
# Out:
# Distribution of daytime vs orders on WEDNESDAYS

# %%
print("Distribution of daytime vs orders on SATURDAYS")
order_id_counts_per_hour = orders.query("order_dow==6")['order_hour_of_day'].value_counts().reset_index()
#print(order_id_counts_per_hour)

order_id_counts_per_hour.columns = ['order_hour_of_day', 'count']
#print(order_id_counts_per_hour)

order_id_counts_per_hour.sort_values(by=['order_hour_of_day'], ascending=True, inplace=True)
#print(order_id_counts_per_hour)

order_id_counts_per_hour.plot(x='order_hour_of_day', y='count', kind='bar')
plt.show()
# Out:
# Distribution of daytime vs orders on SATURDAYS

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * On WEDNESDAYS, peaks are noted at 10-11hs and 15-16hs
#     * On SATURDAYS, peaks are noted at 13-14hs
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Bien, todo es correcto. Sólo pongo el comentario en amarillo para expresarte que, si tu consiguieras armar un dataframe de este tipo:
#
# ![image.png](attachment:image.png)
#
# Entonces con las simples líneas de código de abajo los graficos de las dos series se empalmarán en el mismo espacio.
#
# ![image-2.png](attachment:image-2.png)
#
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
orders_per_client = orders.groupby(['user_id'])['order_number'].max().reset_index().head(20)
orders_per_client.columns = ['user_id', 'order_number_max']
orders_per_client.sort_values(by=['order_number_max'],ascending=False, inplace=True)
print(orders_per_client)

orders_per_client.plot(x='user_id', y='order_number_max', kind='bar')
plt.show()
# Out:
#     user_id  order_number_max
# 12       17                32
# 15       21                26
# 4         7                19
# 10       15                18
# 16       22                15
# 9        14                14
# 8        13                10
# 6        11                 8
# 13       19                 7
# 5        10                 6
# 1         4                 6
# 17       23                 5
# 11       16                 5
# 18       24                 4
# 0         2                 4
# 3         6                 4
# 2         5                 4
# 19       25                 4
# 7        12                 3
# 14       20                 1

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     The chart depicts the 20 customers with the largests amounts of orders.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Otra posible interpretación para esta pregunta es calcular el número de pedidos por usuario:
#
#     order_count_per_user = orders.groupby('user_id')['order_id'].count().sort_values()
#
# Y luego graficar:
#
#     order_count_per_user.plot(kind='hist',
#                           bins=28,
#                           title='Distribution of total orders'
#                          )
#     plt.xlabel('Number of orders')
#     plt.ylabel('Number of customers')
#     plt.show()
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_id_top20 = order_products['product_id'].value_counts().head(20).to_frame().reset_index()
#print(product_id_top20)

product_id_top20.columns = ['product_id', 'count']
#print(product_id_top20)

product_id_top20 = product_id_top20.merge(products[['product_id','product_name']], on='product_id', how='left')
print(product_id_top20)

product_id_top20.plot(kind='bar', x='product_name', y='count', figsize=(10,3))
plt.show()
# Out:
#     product_id  count              product_name
# 0        24852  66050                    BANANA
# 1        13176  53297    BAG OF ORGANIC BANANAS
# 2        21137  37039      ORGANIC STRAWBERRIES
# 3        21903  33971      ORGANIC BABY SPINACH
# 4        47209  29773      ORGANIC HASS AVOCADO
# 5        47766  24689           ORGANIC AVOCADO
# 6        47626  21495               LARGE LEMON
# 7        16797  20018              STRAWBERRIES
# 8        26209  19690                     LIMES
# 9        27845  19600        ORGANIC WHOLE MILK
# 10       27966  19197       ORGANIC RASPBERRIES
# 11       22935  15898      ORGANIC YELLOW ONION
# 12       24964  15292            ORGANIC GARLIC
# 13       45007  14584          ORGANIC ZUCCHINI
# 14       39275  13879       ORGANIC BLUEBERRIES
# 15       49683  13675            CUCUMBER KIRBY
# 16       28204  12544        ORGANIC FUJI APPLE
# 17        5876  12232             ORGANIC LEMON
# 18        8277  11993  APPLE HONEYCRISP ORGANIC
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * The bar chart depicts the 20 most popular products.
#     * This group of 20 products is mostly composed by fruits and vegetables, amidst where we can find that most of them are organic produce.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Cálculos y conclusiones son correctos.
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
print("\nFirstly, let's build a new dataset:")
items_per_order = order_products.groupby(['order_id'])['product_id'].count().sort_values(ascending=False)
print(items_per_order.head())

print("\nSecondly, we will take a look at the dataframe description:")
print(items_per_order.describe())

print("\n\nThirdly, let's analyze the data with the following charts.")
print("\nThe bar chart a whole picture for this large dataset, so let's compare it with a histogram.")

items_per_order.head(20).plot(kind='bar', figsize=(20,5))
plt.show()

items_per_order.hist()
plt.show()
# Out:
# Firstly, let's build a new dataset:
# order_id
# 61355      127
# 3308010    115
# 2136777    108
# 171934     104
# 1959075     98
# Name: product_id, dtype: int64
#
# Secondly, we will take a look at the dataframe description:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64
#
#
# Thirdly, let's analyze the data with the following charts.
#
# The bar chart a whole picture for this large dataset, so let's compare it with a histogram.

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     The chart depicts in a descending fashion the amount of products on each order, filtered by the first 20 large orders. Since the dataframe contains a very large amount of orders, in this case the use of a histogram turns out to be a much better analysis tool.
#     The following observations are the most relevant:
#     * The major part of orders (around 340.000) contain less than 10 different products
#     * There is a significative amount of orders (around 100.000) which contain around 20 different products
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Cálculos y conclusiones son correctos.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atención</b> <a class="tocSkip"></a>
#
# Recomiendo homogeneizar a un sólo idioma el proyecto.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
product_id_top20 = order_products[['product_id', 'reordered']]

product_id_names = products[['product_id', 'product_name']]
#print(product_id_names)

product_id_top20 = product_id_top20.merge(product_id_names, on='product_id', how='left')

product_id_top20 = product_id_top20.groupby('product_name')['reordered'].sum().sort_values(ascending=False).head(20)

print(product_id_top20)

product_id_top20.plot(kind='bar', x='product_name', y='reordered', figsize=(10,3))
plt.show()
# Out:
# product_name
# BANANA                      55763
# BAG OF ORGANIC BANANAS      44450
# ORGANIC STRAWBERRIES        28639
# ORGANIC BABY SPINACH        26233
# ORGANIC HASS AVOCADO        23629
# ORGANIC AVOCADO             18743
# ORGANIC WHOLE MILK          16251
# LARGE LEMON                 15044
# ORGANIC RASPBERRIES         14748
# STRAWBERRIES                13945
# LIMES                       13327
# ORGANIC YELLOW ONION        11145
# ORGANIC GARLIC              10411
# ORGANIC ZUCCHINI            10076
# CUCUMBER KIRBY               9538
# ORGANIC FUJI APPLE           8989
# APPLE HONEYCRISP ORGANIC     8836
# ORGANIC BLUEBERRIES          8799
# ORGANIC LEMON                8412
# ORGANIC HALF & HALF          8389
# Name: reordered, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     The top20 products that are reordered are highly coincident with the results obtained in [B2], regarding the top20 purchased products. This is the expected result.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Correcto.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
product_id_ordered = order_products.groupby(['product_id'])['product_id'].count()
product_id_reordered = order_products.groupby(['product_id'])['reordered'].sum()

product_id_concat = pd.concat([product_id_ordered,product_id_reordered], axis='columns')
product_id_concat.columns = ['ordered', 'reordered']
product_id_concat['proportion_reord_ord'] = product_id_concat['reordered']/product_id_concat['ordered']

product_id_names = products[['product_id', 'product_name']]
product_id_concat = product_id_concat.merge(product_id_names, on='product_id', how='left')
product_id_concat = product_id_concat.sort_values(by='ordered', ascending=False).head(30)

print(product_id_concat)
# Out:
#        product_id  ordered  reordered  proportion_reord_ord  \
# 22808       24852    66050      55763              0.844254
# 12025       13176    53297      44450              0.834006
# 19370       21137    37039      28639              0.773212
# 20077       21903    33971      26233              0.772217
# 43271       47209    29773      23629              0.793639
# 43788       47766    24689      18743              0.759164
# 43663       47626    21495      15044              0.699884
# 15364       16797    20018      13945              0.696623
# 24047       26209    19690      13327              0.676841
# 25556       27845    19600      16251              0.829133
# 25666       27966    19197      14748              0.768245
# 21025       22935    15898      11145              0.701032
# 22908       24964    15292      10411              0.680813
# 41244       45007    14584      10076              0.690894
# 35996       39275    13879       8799              0.633979
# ...

# %%
product_id_concat.plot(kind='bar', x='product_name', y='proportion_reord_ord', figsize=(20,5))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     The table lists for each product the proportion or reordered/ordered, organized in a descending fashion over the field "ordered".
#     If it where not organized in this descending fashion, the filed "proportion_reordered_ordered" would be showing the value "1" which means that the product would have been reordered in the same amount of orders.
#     In this case, probably a bar chart of this indicator is not very tangible of how "good" the product is.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Por atender</b> <a class="tocSkip"></a>
#
# Recomiendo implementar las siguientes líneas de código.
#
#     df_merge = order_products.merge(products)
#     reorder_rate = df_merge.groupby(['product_id', 'product_name'])['reordered'].mean()
#
# La intuición es que la media de una variable dicotómica (1 y 0s) corresponde al porcentaje de observacionenes que registran 1. Luego puedes ordenar de la siguiente forma.
#
#     reorder_rate_as_df = reorder_rate.sort_values(ascending=False).reset_index()
#     reorder_rate_as_df.sort_values(by='product_id')
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
order_users = order_products.merge(orders, on='order_id', how='left')
#print(order_users)

user_id_ordered = order_users.groupby(['user_id'])['product_id'].count()
user_id_reordered = order_users.groupby(['user_id'])['reordered'].sum()

user_id_concat = pd.concat([user_id_ordered,user_id_reordered], axis='columns')
user_id_concat.columns = ['ordered', 'reordered']
user_id_concat['proportion_reord_ord'] = user_id_concat['reordered']/user_id_concat['ordered']

user_id_concat = user_id_concat.sort_values(by='ordered', ascending=False).head(30)

print(user_id_concat)
# Out:
#          ordered  reordered  proportion_reord_ord
# user_id
# 103634       580        477              0.822414
# 33731        540        437              0.809259
# 137629       526        444              0.844106
# 23371        506        428              0.845850
# 164055       504        449              0.890873
# 59819        481        436              0.906445
# 4694         480        386              0.804167
# 186704       467        410              0.877944
# 166951       458        402              0.877729
# 201268       457        401              0.877462
# 129928       448        413              0.921875
# 193056       437        364              0.832952
# 100787       427        356              0.833724
# 176478       426        340              0.798122
# 6710         425        358              0.842353
# 136896       422        366              0.867299
# 106161       411        308              0.749392
# 60694        409        208              0.508557
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     The table provides a list for each customer and its total of orders and reorders, and its proportion. The list is organized on a descending fashion over the field "ordered", filtering the first 30 lines.
#     While it is showing the customer that make the most amount of orders, this does not mean that these are the most valuable customer in terms of money since we are not evaluating financial weight of each customer.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Por atender</b> <a class="tocSkip"></a>
#
# De manera similar a la pregunta anterior, aquí puedes aplicar:
#
#     df_merge = order_products.merge(orders)
#     reorder_pct = df_merge.groupby('user_id')['reordered'].mean()
#     reorder_pct_as_df = reorder_pct.sort_values(ascending=False).reset_index()
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
products_first_order = order_products.query("add_to_cart_order==1")
products_first_order = products_first_order.merge(products, on='product_id',how='left')
products_first_order = products_first_order.groupby('product_name')['add_to_cart_order'].sum().sort_values(ascending=False).head(20)

print(products_first_order)
# Out:
# product_name
# BANANA                         15562.0
# BAG OF ORGANIC BANANAS         11026.0
# ORGANIC WHOLE MILK              4363.0
# ORGANIC STRAWBERRIES            3946.0
# ORGANIC HASS AVOCADO            3390.0
# ORGANIC BABY SPINACH            3336.0
# ORGANIC AVOCADO                 3044.0
# SPRING WATER                    2336.0
# STRAWBERRIES                    2308.0
# ORGANIC RASPBERRIES             2024.0
# SPARKLING WATER GRAPEFRUIT      1914.0
# ORGANIC HALF & HALF             1797.0
# LARGE LEMON                     1737.0
# SODA                            1733.0
# ORGANIC REDUCED FAT MILK        1397.0
# LIMES                           1370.0
# HASS AVOCADOS                   1340.0
# ORGANIC REDUCED FAT 2% MILK     1310.0
# HALF & HALF                     1309.0
# ORGANIC YELLOW ONION            1246.0
# Name: add_to_cart_order, dtype: float64

# %%
products_first_order.plot(kind='bar', figsize=(20,5))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# Conclusiones
#
#     * Bananas and organic bananas are the very first products added to the cart (order). It looks like bananas are a highly demanded product.
#     * This list of top20 products that are firstly included in the order contains mainly fruits and vegetables, which depicts the customers make mostly healthy choices when they do their groceries.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Buen trabajo</b> <a class="tocSkip"></a>
#
# Cálculos y conclusiones correctas.
#
# </div>
